# %% [markdown]
# ## Time Series Forecasting Framework

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing Dataset

# %%
data = pd.read_csv(r"D:\Learning\SL---Time-Series-Analysis\data\yahoo_stock.csv")

# %%
data.head()
# Out:
#          Date         High          Low         Open        Close  \
# 0  2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088
# 1  2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893
# 2  2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117
# 3  2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117
# 4  2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107
#
#          Volume    Adj Close
# 0  3.587980e+09  2086.590088
# 1  3.884930e+09  2089.139893
# 2  2.852940e+09  2088.870117
# 3  2.852940e+09  2088.870117
# 4  1.466840e+09  2090.110107

# %%
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')

# %% [markdown]
# # Data Preparation

# %%
class DataPrep:
    
    def __init__(self,data=None, cat=False):
        self.full_df = data
        self.isCat = cat               
        
    def get_target(self, target_name):
        data = self.full_df.copy()
        self.target = data[[target_name]]
    
    def resample_data(self, data, resample_freq):
        data = data.resample(resample_freq).sum()
    
    def create_feat(self, data):
        
        range_num = list(range(2, 12))
        
        #create features for continuous
        for num in range_num:

            col_name = col + "_rollmean_" + str(num)

# %% [markdown]
# # Feature Engineering

# %%
class ContFE:
    """
        This class create statistical features from the data - Applicable to Continuous Data
    """
    
    def __init__(self, data=None):
        
        self.data = data
    
    def rolling_windows(self, max_range=12):
        """
            Create Rolling Windows
            1. Mean
            2. Median
            3. Min
            4. Max
            5. Sum
            6. Variance
            7. Correlation
            8. Covariance
            9. Quantile
            10. SEM
            11. Skewness
            12. Kurtosis
            13. Count
            
            This is based on the max range
        """
        
        time_range = list(range(2, max_range))
        
        
        for col in self.data.columns:
            for _ in time_range:
                
                #Rolling Mean
                col_name = col + "_rollmean_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).mean()
                
                #Rolling Median
                col_name = col + "_rollmedian_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).median()
                
                #Rolling Min
                col_name = col + "_rollmin_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).min()
                
                #Rolling Max
                col_name = col + "_rollmax_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).max()
                
                #Rolling Sum
                col_name = col + "_rollsum_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).sum()
                
                #Rolling Variance
                col_name = col + "_rollvar_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).var()
                
                #Rolling Correlation
                col_name = col + "_rollcorr_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).corr()
                
                #Rolling Covariance
                col_name = col + "_rollcov_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).cov()
                
                #Rolling Quantile
                col_name = col + "_rollquant_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).quantile()
                
                #Rolling SEM
                col_name = col + "_rollsem_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).sem()
                
                #Rolling Skewness
                col_name = col + "_rollskew_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).skew()
                
                #Rolling Kurtosis
                col_name = col + "_rollkurt_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).kurt()
                
                #Rolling Count
                col_name = col + "_rollcount_" + str(_)
                self.data[col_name] = self.data[col].rolling(_).count()
                
    
    def expand_windows(self):
        """
            Create Expanding Windows
            1. Mean
            2. Median
            3. Min
            4. Max
            5. Sum
            6. Variance
            7. Correlation
            8. Covariance
            9. Quantile
            10. SEM
            11. Skewness
            12. Kurtosis
            13. Count
            
            This is based on the max range
        """
        
        time_range = list(range(2, max_range))
        
        
        for col in self.data.columns:
            for _ in time_range:
                
                #expanding Mean
                col_name = col + "_expmean_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).mean()
                
                #expanding Median
                col_name = col + "_expmedian_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).median()
                
                #expanding Min
                col_name = col + "_expmin_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).min()
                
                #expanding Max
                col_name = col + "_expmax_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).max()
                
                #expanding Sum
                col_name = col + "_expsum_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).sum()
                
                #expanding Variance
                col_name = col + "_expvar_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).var()
                
                #expanding Correlation
                col_name = col + "_expcorr_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).corr()
                
                #expanding Covariance
                col_name = col + "_expcov_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).cov()
                
                #expanding Quantile
                col_name = col + "_expquant_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).quantile()
                
                #expanding SEM
                col_name = col + "_expsem_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).sem()
                
                #expanding Skewness
                col_name = col + "_expskew_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).skew()
                
                #expanding Kurtosis
                col_name = col + "_expkurt_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).kurt()
                
                #expanding Count
                col_name = col + "_expcount_" + str(_)
                self.data[col_name] = self.data[col].expanding(_).count()
        
    
    
    def exponential_weighted(self):
        """
            Create Exponential Weighted Moving
            
            1. Average
            2. Standard Deviation
            3. Variance
            4. Correlation
            5. Covariance
        """
        
        time_range = list(range(2, max_range))
        
        
        for col in self.data.columns:
            for _ in time_range:
                
                #Exponential Weighted Mean
                col_name = col + "_ewmmean_" + str(_)
                self.data[col_name] = self.data[col].ewm(span = _).mean()
                
                #Exponential Weighted Standard Deviation
                col_name = col + "_ewmstd_" + str(_)
                self.data[col_name] = self.data[col].ewm(span = _).std()
                
                
                #Exponential Weighted Variance
                col_name = col + "_ewmvar_" + str(_)
                self.data[col_name] = self.data[col].ewm(span = _).var()
                
                
                #Exponential Weighted Correlation
                col_name = col + "_ewmcorr_" + str(_)
                self.data[col_name] = self.data[col].ewm(span = _).corr()
                
                
                #Exponential Weighted Covariance
                col_name = col + "_ewmcov_" + str(_)
                self.data[col_name] = self.data[col].ewm(span = _).cov()
                
        
    
    def roc(self):
        """
            Create mathematical Functions for
            1. Rate of Change
            2. Percentage of Change
            3. Derivative / Gradient
        """
    
    
    def math_func(self):
        """
            Create Mathematical Functions
            1. Power - Power of 2,3,4,5
            2. Root - Power of 1/2, 1/3, 1/4, 1/5
            3. Logarithm (if only more than 1)
            4. 
        
        """

# %% [markdown]
# # Feature Selection

# %%
class FeatureSelection:
    
    def __init__(self):
        pass

# %%
# %config Completer.use_jedi = False
